# %% [markdown]
# # Import Airfoil design Dataset

# %% [markdown]
# The aim of this notebook is to shows how the challenge datasets could be downloaded and imported using LIPS features.

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# Install the LIPS framework if it is not already done. For more information look at the LIPS framework [Github repository](https://github.com/IRT-SystemX/LIPS)

# %%
# !pip install -r requirements.txt
# or 
#!pip install -U .
# Out:
# Requirement already satisfied: filelock==3.7.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: Grid2Op==1.9.8 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 2)) (1.9.8)
# Requirement already satisfied: json2table==1.1.5 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 3)) (1.1.5)
# Requirement already satisfied: leap-net==0.0.5 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 4)) (0.0.5)
# Requirement already satisfied: lightsim2grid==0.8.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 5)) (0.8.1)
# Requirement already satisfied: loguru==0.6.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: numpy==1.25.2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 7)) (1.25.2)
# Requirement already satisfied: numba==0.59.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 8)) (0.59.1)
# Requirement already satisfied: pandapower in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: pandas==1.5.3 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: pathlib==1.0.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: protobuf in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 12)) (4.25.8)
# Requirement already satisfied: pybind11==2.8.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 13)) (2.8.1)
# Requirement already satisfied: pytest==6.2.5 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 14)) (6.2.5)
# Requirement already satisfied: pytest-cov==3.0.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: pytest-html==3.1.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 16)) (3.1.1)
# Requirement already satisfied: pytest-metadata==1.11.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 17)) (1.11.0)
# Requirement already satisfied: PyYAML==6.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 18)) (6.0)
# Requirement already satisfied: scikit-learn in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 19)) (1.8.0)
# Requirement already satisfied: scipy==1.11.4 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 20)) (1.11.4)
# Requirement already satisfied: six==1.16.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 21)) (1.16.0)
# Requirement already satisfied: tqdm==4.62.3 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 22)) (4.62.3)
# Requirement already satisfied: tensorflow in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 23)) (2.17.1)
# Requirement already satisfied: torch==2.0.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 24)) (2.0.1)
# Requirement already satisfied: imageio==2.34.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 25)) (2.34.0)
# Requirement already satisfied: plotly==5.20.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from -r requirements.txt (line 26)) (5.20.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from Grid2Op==1.9.8->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from Grid2Op==1.9.8->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: packaging in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from Grid2Op==1.9.8->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: typing-extensions in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from Grid2Op==1.9.8->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from loguru==0.6.0->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from loguru==0.6.0->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from numba==0.59.1->-r requirements.txt (line 8)) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pandas==1.5.3->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pandas==1.5.3->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (25.4.0)
# Requirement already satisfied: iniconfig in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (2.3.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (1.6.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (1.11.0)
# Requirement already satisfied: toml in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 14)) (1.4.1)
# Requirement already satisfied: coverage>=5.2.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from coverage[toml]>=5.2.1->pytest-cov==3.0.0->-r requirements.txt (line 15)) (7.13.2)
# Requirement already satisfied: sympy in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from torch==2.0.1->-r requirements.txt (line 24)) (1.13.1)
# Requirement already satisfied: jinja2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from torch==2.0.1->-r requirements.txt (line 24)) (3.1.6)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from imageio==2.34.0->-r requirements.txt (line 25)) (12.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from plotly==5.20.0->-r requirements.txt (line 26)) (9.1.2)
# Requirement already satisfied: deepdiff in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pandapower->-r requirements.txt (line 9)) (8.6.1)
# Requirement already satisfied: geojson in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pandapower->-r requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: lxml in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from pandapower->-r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 19)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 19)) (3.6.0)
# Requirement already satisfied: tensorflow-intel==2.17.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow->-r requirements.txt (line 23)) (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.4.0)
# Requirement already satisfied: setuptools in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (1.76.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from requests>=2.23.0->Grid2Op==1.9.8->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from requests>=2.23.0->Grid2Op==1.9.8->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from requests>=2.23.0->Grid2Op==1.9.8->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from requests>=2.23.0->Grid2Op==1.9.8->-r requirements.txt (line 2)) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.46.3)
# Requirement already satisfied: rich in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (14.3.1)
# Requirement already satisfied: namex in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.1.0)
# Requirement already satisfied: optree in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (2.1.5)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from deepdiff->pandapower->-r requirements.txt (line 9)) (5.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow->-r requirements.txt (line 23)) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dlals\desktop\neurips2024-ml4cfd-competition-starting-kit-main\venv\lib\site-packages (from sympy->torch==2.0.1->-r requirements.txt (line 24)) (1.3.0)

# %% [markdown]
# Install the AirfRANS package

# %%
# !pip install airfrans

# %%
#### Import required packages
import os
from lips import get_root_path
from lips.dataset.airfransDataSet import download_data
from lips.benchmark.airfransBenchmark import AirfRANSBenchmark

# %%
# indicate required paths
LIPS_PATH = get_root_path()
DIRECTORY_NAME = 'Dataset'
BENCHMARK_NAME = "Case1"
LOG_PATH = LIPS_PATH + "lips_logs.log"

# %% [markdown]
# Define the configuration files path.

# %%
BENCH_CONFIG_PATH = os.path.join("airfoilConfigurations","benchmarks","confAirfoil.ini") #Configuration file related to the benchmark

# %% [markdown]
# Download the data

# %%
if not os.path.isdir(DIRECTORY_NAME):
    download_data(root_path=".", directory_name=DIRECTORY_NAME)

# %% [markdown]
# In order to load the data on disk, we rely on the `load` method of the dedicated benchmark class. On could also load individually each dataset if required.
#
# However, note that in the context of this competition, the datasets considered are loaded by using the airfrans dataset but with some modifications, namely:
#
# - Train dataset: 'scarce' task, training split, filtered to keep the simulation where the number of reynolds is between 3e6  and 5e6
# - Test dataset: 'full' task, testing split
# - OOD dataset: reynolds task, testing split

# %%
benchmark=AirfRANSBenchmark(benchmark_path = DIRECTORY_NAME,
                            config_path = BENCH_CONFIG_PATH,
                            benchmark_name = BENCHMARK_NAME,
                            log_path = LOG_PATH)
benchmark.load(path=DIRECTORY_NAME)
# Out:
# Loading dataset (task: scarce, split: train): 100%|██████████| 200/200 [00:59<00:00,  3.36it/s]
# Loading dataset (task: full, split: test): 100%|██████████| 200/200 [00:58<00:00,  3.42it/s]
# Loading dataset (task: reynolds, split: test): 100%|██████████| 496/496 [02:37<00:00,  3.15it/s]

# %% [markdown]
# We can also have a look at the datasets loaded (meaning all the features, labels)

# %%
print("train dataset: ", benchmark.train_dataset)
print("test dataset: ", benchmark._test_dataset )
print("test dataset: ", benchmark._test_ood_dataset )
# Out:
# train dataset:  Instance of AirfRANSDataSet
# Dataset name: train
# 	x-position
# 		 Data size: (18515415,)
# 	y-position
# 		 Data size: (18515415,)
# 	x-inlet_velocity
# 		 Data size: (18515415,)
# 	y-inlet_velocity
# 		 Data size: (18515415,)
# 	distance_function
# 		 Data size: (18515415,)
# 	x-normals
# 		 Data size: (18515415,)
# 	y-normals
# 		 Data size: (18515415,)
# 	x-velocity
# 		 Data size: (18515415,)
# 	y-velocity
# 		 Data size: (18515415,)
# 	pressure
# 		 Data size: (18515415,)
# 	turbulent_viscosity
# 		 Data size: (18515415,)
#
# test dataset:  Instance of AirfRANSDataSet
# Dataset name: test
# 	x-position
# 		 Data size: (35849332,)
# 	y-position
# 		 Data size: (35849332,)
# 	x-inlet_velocity
# 		 Data size: (35849332,)
# 	y-inlet_velocity
# 		 Data size: (35849332,)
# 	distance_function
# 		 Data size: (35849332,)
# 	x-normals
# 		 Data size: (35849332,)
# 	y-normals
# 		 Data size: (35849332,)
# 	x-velocity
# 		 Data size: (35849332,)
# 	y-velocity
# 		 Data size: (35849332,)
# 	pressure
# 		 Data size: (35849332,)
# 	turbulent_viscosity
# 		 Data size: (35849332,)
#
# test dataset:  Instance of AirfRANSDataSet
# Dataset name: test_ood
# 	x-position
# 		 Data size: (89074648,)
# 	y-position
# 		 Data size: (89074648,)
# 	x-inlet_velocity
# 		 Data size: (89074648,)
# 	y-inlet_velocity
# 		 Data size: (89074648,)
# 	distance_function
# 		 Data size: (89074648,)
# 	x-normals
# 		 Data size: (89074648,)
# 	y-normals
# 		 Data size: (89074648,)
# 	x-velocity
# 		 Data size: (89074648,)
# 	y-velocity
# 		 Data size: (89074648,)
# 	pressure
# 		 Data size: (89074648,)
# 	turbulent_viscosity
# 		 Data size: (89074648,)

# %% [markdown]
# For each dataset, the number of samples within it is the overall number of nodes in the whole dataset. Therefore, each variable within the dataset arises from the concatenation of each nodal quantities
#
# Thus, it can also be intesresting to retrieve the number of physical simulation in each of them. It can be done with the method `get_simulations_sizes` from the `Dataset` class.

# %%
for datasetName,dataset in zip(["Train","Test","OOD"],[benchmark.train_dataset,benchmark._test_dataset,benchmark._test_ood_dataset]):
    print("%s dataset: "%datasetName)
    print("\t Number of simulations:", len(dataset.get_simulations_sizes()))
# Out:
# Train dataset:
# 	 Number of simulations: 103
# Test dataset:
# 	 Number of simulations: 200
# OOD dataset:
# 	 Number of simulations: 496
